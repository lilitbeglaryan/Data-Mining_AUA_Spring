# %% [markdown]
# # Lilit Beglaryan

# %% [markdown]
# ## About data:
#
# The main goal is to analyze the relationship between the characteristics of respondents and their GPA. The description of the variables is given bellow:
#
# * studentid -- ID of Respondent
# * surveydate -- Survey conducting day
#
# * age -- Age of Respondent
# * ehpw -- Hours spent on extracurricular activities a week
# * hpw -- Hours spent on studying a week
# * hsleep -- Hours of sleep per day
# * GPA -- Grand point average of student [0-100]
#
# * gender -- 0:male, 1:female
# * job -- 1:Respondent has a job 0:Respondent does not have a job
# * type -- 0: part-time 1: full-time
#
# * marital.status
#     1. single -- Respondent is single and has never been married
#     2. married -- Respondent is married
#     3. divorced -- Respondent is divorced or widowed
#
#
# * imp -- Importance of geting/maintaining a high GPA (85 or greater)?
# 	1: Not Important - 5: Very Important

# %%
import numpy as np 
import pandas as pd
print(np.__version__)
# Out:
# 1.24.1

# %% [markdown]
# ## Part 1: Introduction to data

# %%
main_data = pd.read_csv("gpafactors.csv")

# %%
main_data.head()
# Out:
#    Unnamed: 0  studentid surveydate   age  ehpw   hpw  hsleep    gpa  imp  \
# 0           1      57327   4/1/2018   NaN  24.0  16.0    6.29  46.35    5
# 1           2        231   1/1/2018  18.0  13.0   9.0    8.86  36.84    1
# 2           3      10474  1/17/2018  26.0  20.0  19.0    6.43  65.07    5
# 3           4       8654  1/14/2018  20.0  19.0  11.0    7.71  33.87    2
# 4           5      80185   5/7/2018  27.0  19.0  21.0    6.29  65.52    2
#
#    gender     job       type marital.status
# 0    male    empl   par-time         single
# 1  female    empl   par-time         single
# 2    male  unempl  full-time       divorced
# 3  female    empl   par-time         single
# 4    male  unempl  full-time       divorced

# %%
# Removing columns that don't have any description
del main_data["Unnamed: 0"]

# %%
main_data.head()
# Out:
#    studentid surveydate   age  ehpw   hpw  hsleep    gpa  imp  gender     job  \
# 0      57327   4/1/2018   NaN  24.0  16.0    6.29  46.35    5    male    empl
# 1        231   1/1/2018  18.0  13.0   9.0    8.86  36.84    1  female    empl
# 2      10474  1/17/2018  26.0  20.0  19.0    6.43  65.07    5    male  unempl
# 3       8654  1/14/2018  20.0  19.0  11.0    7.71  33.87    2  female    empl
# 4      80185   5/7/2018  27.0  19.0  21.0    6.29  65.52    2    male  unempl
#
#         type marital.status
# 0   par-time         single
# 1   par-time         single
# 2  full-time       divorced
# 3   par-time         single
# 4  full-time       divorced

# %%
# Extracting info about each column. This will help to understand if any column has a missing value or not
main_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   studentid       2000 non-null   int64
#  1   surveydate      2000 non-null   object
#  2   age             1998 non-null   float64
#  3   ehpw            1999 non-null   float64
#  4   hpw             1998 non-null   float64
#  5   hsleep          1998 non-null   float64
#  6   gpa             2000 non-null   float64
#  7   imp             2000 non-null   int64
#  8   gender          1999 non-null   object
#  9   job             1999 non-null   object
#  10  type            2000 non-null   object
#  11  marital.status  1999 non-null   object
# dtypes: float64(5), int64(2), object(5)
# memory usage: 187.6+ KB

# %% [markdown]
# As we can see from the info summary age, ehpw, hsleep gender job and marital.status have missing values.

# %% [markdown]
# ##  Handling Missing values

# %% [markdown]
# * Drop rows/columns that contain missing values
# * Fill in missing values
#     1. In case of numeric variables most common technique is filling with mean or median
#     2. In case of categorical variables with the most frequent one (mode)

# %%
main_data.dropna(subset = ["age"], inplace = True)

# %%
main_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1998 entries, 1 to 1999
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   studentid       1998 non-null   int64
#  1   surveydate      1998 non-null   object
#  2   age             1998 non-null   float64
#  3   ehpw            1997 non-null   float64
#  4   hpw             1996 non-null   float64
#  5   hsleep          1996 non-null   float64
#  6   gpa             1998 non-null   float64
#  7   imp             1998 non-null   int64
#  8   gender          1997 non-null   object
#  9   job             1997 non-null   object
#  10  type            1998 non-null   object
#  11  marital.status  1997 non-null   object
# dtypes: float64(5), int64(2), object(5)
# memory usage: 202.9+ KB

# %%
main_data.fillna(main_data.mean(numeric_only=True).round(1), inplace = True)
# main_data.select_dtypes(np.number).info()

# %%
main_data.info()
main_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1998 entries, 1 to 1999
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1998 non-null   int64
#  1   studentid       1998 non-null   int64
#  2   surveydate      1998 non-null   object
#  3   age             1998 non-null   float64
#  4   ehpw            1998 non-null   float64
#  5   hpw             1998 non-null   float64
#  6   hsleep          1998 non-null   float64
#  7   gpa             1998 non-null   float64
#  8   imp             1998 non-null   int64
#  9   gender          1998 non-null   object
#  10  job             1998 non-null   object
#  11  type            1998 non-null   object
#  12  marital.status  1998 non-null   object
# dtypes: float64(5), int64(3), object(5)
# memory usage: 218.5+ KB
#    Unnamed: 0  studentid surveydate   age  ehpw   hpw  hsleep    gpa  imp  \
# 1           2        231   1/1/2018  18.0  13.0   9.0    8.86  36.84    1
# 2           3      10474  1/17/2018  26.0  20.0  19.0    6.43  65.07    5
# 3           4       8654  1/14/2018  20.0  19.0  11.0    7.71  33.87    2
# 4           5      80185   5/7/2018  27.0  19.0  21.0    6.29  65.52    2
# 5           6      69894  4/21/2018  21.0  14.0  13.0    8.14  48.61    3
#
#    gender     job       type marital.status
# 1  female    empl   par-time         single
# 2    male  unempl  full-time       divorced
# 3  female    empl   par-time         single
# 4    male  unempl  full-time       divorced
# 5  female    empl   par-time         single

# %%
main_data.fillna(main_data.mode().iloc[0], inplace = True)

# %%
main_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1998 entries, 1 to 1999
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   studentid       1998 non-null   int64
#  1   surveydate      1998 non-null   object
#  2   age             1998 non-null   float64
#  3   ehpw            1998 non-null   float64
#  4   hpw             1998 non-null   float64
#  5   hsleep          1998 non-null   float64
#  6   gpa             1998 non-null   float64
#  7   imp             1998 non-null   int64
#  8   gender          1998 non-null   object
#  9   job             1998 non-null   object
#  10  type            1998 non-null   object
#  11  marital.status  1998 non-null   object
# dtypes: float64(5), int64(2), object(5)
# memory usage: 202.9+ KB

# %% [markdown]
# ## Checking values of data

# %%
main_data.describe()
# Out:
#           studentid          age         ehpw          hpw       hsleep  \
# count   1998.000000  1998.000000  1998.000000  1998.000000  1998.000000
# mean   49943.434935    23.383383    20.039039    14.943443     7.004735
# std    28908.774357     7.230808     3.042427     4.899215     0.827695
# min       74.000000    16.000000    10.000000     1.000000     3.710000
# 25%    25297.500000    21.000000    18.000000    12.000000     6.430000
# 50%    49350.000000    23.000000    20.000000    15.000000     7.000000
# 75%    74586.750000    26.000000    22.000000    18.000000     7.570000
# max    99986.000000   304.000000    29.000000    33.000000     9.430000
#
#               gpa          imp
# count  1998.00000  1998.000000
# mean     49.27485     3.008509
# std      15.81980     1.423189
# min       2.60000     1.000000
# 25%      38.46000     2.000000
# 50%      49.01000     3.000000
# 75%      59.65000     4.000000
# max      99.50000     5.000000

# %% [markdown]
# **Do you see any problems here?**

# %%
main_data = main_data[main_data['age']!= 304]

# %%
main_data.describe()
# Out:
#           studentid          age         ehpw          hpw       hsleep  \
# count   1996.000000  1996.000000  1996.000000  1996.000000  1996.000000
# mean   49945.719439    23.245992    20.039078    14.941884     7.004955
# std    28915.542321     3.581365     3.043787     4.901192     0.828005
# min       74.000000    16.000000    10.000000     1.000000     3.710000
# 25%    25280.250000    21.000000    18.000000    12.000000     6.430000
# 50%    49350.000000    23.000000    20.000000    15.000000     7.000000
# 75%    74595.500000    26.000000    22.000000    18.000000     7.570000
# max    99986.000000    35.000000    29.000000    33.000000     9.430000
#
#                gpa          imp
# count  1996.000000  1996.000000
# mean     49.269449     3.008517
# std      15.823854     1.422493
# min       2.600000     1.000000
# 25%      38.450000     2.000000
# 50%      49.010000     3.000000
# 75%      59.630000     4.000000
# max      99.500000     5.000000

# %%
main_data.describe(include = 'object')
# Out:
#        gender     job      type marital.status
# count    1996    1996      1996           1996
# unique      2       2         2              3
# top      male  unempl  par-time         single
# freq     1051    1028      1082           1376

# %% [markdown]
# **Do you see any problems here?**

# %%
np.unique(main_data['gender'])
# Out:
# array(['.', 'female', 'male'], dtype=object)

# %%
main_data = main_data[main_data['gender']!= "."]

# %%
main_data.describe(include = 'object')
# Out:
#        surveydate gender     job      type marital.status
# count        1996   1996    1996      1996           1996
# unique        158      2       2         2              3
# top     3/11/2018   male  unempl  par-time         single
# freq           24   1051    1028      1082           1376

# %% [markdown]
# **Anything else?**

# %%
main_data["surveydate"] = pd.to_datetime(main_data["surveydate"])

# %% [markdown]
# ## Reseting Index

# %%
main_data.head()
main_data.describe()
# Out:
#           studentid          age         ehpw          hpw       hsleep  \
# count   1996.000000  1996.000000  1996.000000  1996.000000  1996.000000
# mean   49945.719439    23.245992    20.039078    14.941884     7.004955
# std    28915.542321     3.581365     3.043787     4.901192     0.828005
# min       74.000000    16.000000    10.000000     1.000000     3.710000
# 25%    25280.250000    21.000000    18.000000    12.000000     6.430000
# 50%    49350.000000    23.000000    20.000000    15.000000     7.000000
# 75%    74595.500000    26.000000    22.000000    18.000000     7.570000
# max    99986.000000    35.000000    29.000000    33.000000     9.430000
#
#                gpa          imp
# count  1996.000000  1996.000000
# mean     49.269449     3.008517
# std      15.823854     1.422493
# min       2.600000     1.000000
# 25%      38.450000     2.000000
# 50%      49.010000     3.000000
# 75%      59.630000     4.000000
# max      99.500000     5.000000

# %%
main_data.reset_index(drop = True, inplace = True)
main_data.reset_index(drop = True, inplace = True)
main_data.reset_index(drop = True, inplace = True)

# %%
main_data.head()
# main_data.describe()
# Out:
#    studentid surveydate   age  ehpw   hpw  hsleep    gpa  imp  gender     job  \
# 0        231 2018-01-01  18.0  13.0   9.0    8.86  36.84    1  female    empl
# 1      10474 2018-01-17  26.0  20.0  19.0    6.43  65.07    5    male  unempl
# 2       8654 2018-01-14  20.0  19.0  11.0    7.71  33.87    2  female    empl
# 3      80185 2018-05-07  27.0  19.0  21.0    6.29  65.52    2    male  unempl
# 4      69894 2018-04-21  21.0  14.0  13.0    8.14  48.61    3  female    empl
#
#         type marital.status
# 0   par-time         single
# 1  full-time       divorced
# 2   par-time         single
# 3  full-time       divorced
# 4   par-time         single
